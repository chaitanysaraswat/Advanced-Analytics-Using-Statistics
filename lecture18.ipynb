# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitanysaraswat/Advanced-Analytics-Using-Statistics/blob/main/lecture18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DECISION TREE
#
#
# EASY <--CERTAINITY<--LESS VARIATION<--LESS VARIANCE/STANDARD DEVIATION
# IF YOUR PROPORTION IS P THEN
# - VARIANCE=P*(1-P)
# - SQUAREOOT(VARIANCE)
# - AT WHAT STAGE  IS HOW SHOULD ASK
# - AT CLEAR SPLIT WHERE LESS VARAITION

# %% [markdown]
# np.median all np  will give nan if there is missing values
#
# so we use df.column.median()

# %%
import pandas as pd
df=pd.read_csv("/content/drive/MyDrive/CDAC_stats/Titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df=df.drop(['PassengerId','Name','Ticket','Cabin'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Sex       891 non-null    object
#  3   Age       714 non-null    float64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Fare      891 non-null    float64
#  7   Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.8+ KB

# %%
df.Age = df.Age.fillna(df.Age.median())
df.Embarked.mode()
df.Embarked = df.Embarked.fillna('S')

df['NumPass'] = df.SibSp + df.Parch
df = df.drop(['SibSp','Parch'], axis=1)

dum_Pclass = pd.get_dummies(df.Pclass,drop_first=True,prefix='Pclass').astype(int)
dum_sex = pd.get_dummies(df.Sex,drop_first=True,prefix='Gender').astype(int)
dum_embarked = pd.get_dummies(df.Embarked,drop_first=True,prefix='Embark').astype(int)

df = df.drop(['Pclass','Sex','Embarked'],axis=1)
df = pd.concat([df,dum_Pclass,dum_sex,dum_embarked], axis=1)

# %%
df.head()
# Out:
#    Survived   Age     Fare  NumPass  Pclass_2  Pclass_3  Gender_male  \
# 0         0  22.0   7.2500        1         0         1            1
# 1         1  38.0  71.2833        1         0         0            0
# 2         1  26.0   7.9250        0         0         1            0
# 3         1  35.0  53.1000        1         0         0            0
# 4         0  35.0   8.0500        0         0         1            1
#
#    Embark_Q  Embark_S
# 0         0         1
# 1         0         0
# 2         0         1
# 3         0         1
# 4         0         1

# %%
x=df.drop('Survived',axis=1)
y=df.Survived

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
import statsmodels.stats.multicomp
import sklearn
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
from numpy import random
from collections import Counter
from numpy.linalg import inv
from numpy.linalg import eig
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
import pylab
from pylab import legend
from pylab import plot, show, title, xlabel, ylabel
import scipy
from scipy import stats
from scipy.stats import binom,poisson,norm,t,expon,f
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# give me model of overfiting happen
#
# - when we Decision tree classifier without specifing any hyperparameter
# becoz we seen big gap b/w train and test score accuracy
#
# - models are good that work on test data not on train data below is the example we are okay to give train accuracy if test accuracy increases  i.e  bias variance tradeoff.
#
# - if percentage change b/w train and test output accuracy is greater than 10 overfitiing
# less than 5 underfitting and 5-10 dicey
# - if we want to remove overfitting use max_depth 3,4,5
#
# - if train accuracy is coming down then probably noise factor is coming down
#
# - atleat 4 hyperparameter in decision tree  you should give to remove overfitting like
#
# - max_depth,
#
# - min_sample_split,
#
# - min_samples_leaf,
#
# - criterion
#
# - min_impurity_decrease
#
# ---
# 1 entropy total randomness 1
#
# entropy means randomness
#
# if randomness more high variation more uncertainity

# %% [markdown]
# Accuracy: The overall correctness of the model.
#
# Precision: The reliability of the model when it predicts a positive class.
#
# Recall: The model’s ability to find all actual positive cases

# %%
x=df.drop('Survived',axis=1)
y=df.Survived

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=20)

from sklearn.tree import DecisionTreeClassifier# for continuous data we us decisiontree regressor

dtc = DecisionTreeClassifier(max_depth=3)

dtc.fit(x_train,y_train)
print(dtc.score(x_train,y_train) )# percentage accuracy on train test
dtc.score(x_test,y_test)
# Out:
# 0.8258426966292135
# 0.8156424581005587

# %%
dtc = DecisionTreeClassifier(max_depth=3)
dtc
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
param = {'max_depth':[2,3,4,5,6,7,8],
         'splitter':['best','random'],
         'criterion':['gini','entropy'],
         'min_samples_leaf':[2,3,4,5,6]}

from sklearn.model_selection import GridSearchCV

mod1 = GridSearchCV(dtc,param_grid=param,cv=5,scoring='accuracy')

mod1.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(max_depth=3),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 4, 5, 6, 7, 8],
#                          'min_samples_leaf': [2, 3, 4, 5, 6],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy')

# %%
print(mod1.best_params_)
# Out:
# {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 5, 'splitter': 'random'}

# %%
x=df.drop('Survived',axis=1)
y=df.Survived

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=20)

from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier(criterion= 'entropy', max_depth= 5, min_samples_leaf= 5, splitter= 'random')

dtc.fit(x_train,y_train)#r square of seen data
print(dtc.score(x_train,y_train) )# percentage accuracy on train test
dtc.score(x_test,y_test)
# Out:
# 0.8230337078651685
# 0.8156424581005587

# %% [markdown]
# GINI IMPURITY WILL BE HIGHEST WHEN IT IS 50/50 SPLIT SO GINI IMPURITY IS 0.5 WHICH IS HIGHEST
#
# GINI IMPURITY WILL BE LOWEST WHEN IT IS CLEAR  SPLIT(90/10) SO GINI IMPURITY IS 0.1 OR 0 WHICH IS LOWEST
#
# GINI IMPURITY

# %%
df = pd.read_excel('/content/drive/MyDrive/CDAC_stats/SalesData.xlsx')
dum_Region = pd.get_dummies(df.Region,drop_first=True,prefix='Reg').astype(int)
df = df.drop('Region', axis=1)
df = pd.concat([df,dum_Region], axis=1)

x = df.drop('Sales', axis=1)
y = df.Sales

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=20)

from sklearn.tree import DecisionTreeRegressor

# define instance for DecisionTreeClassifier WITHOUT hyperparameters
dtr = DecisionTreeRegressor()# for categorical data we us decisiontree regressor
dtr.fit(x_train,y_train)
print(dtr.score(x_train,y_train))
dtr.score(x_test,y_test)
# Out:
# 1.0
# 0.8547296348209935

# %%
from sklearn.metrics import r2_score
y_pred=dtr.predict(x_test)
r2_score(y_test,y_pred)
mod1.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 5,
#  'min_samples_leaf': 5,
#  'splitter': 'random'}

# %%
from sklearn.metrics import r2_score
y_pred = dtr.predict(x_test)
r2_score(y_test,y_pred)

params = {'max_depth':[3,4,5,6,7],
          'min_samples_split':[2,3,4,5],
          'min_samples_leaf':[2,3,4,5]}

mod1 = GridSearchCV(dtr,param_grid=params,cv=5,scoring='accuracy')
mod1.fit(x_train, y_train)
mod1.best_params_


dtr = DecisionTreeRegressor(max_depth=3,min_samples_leaf=2, min_samples_split=2)
dtr.fit(x_train,y_train)
print(dtr.score(x_train,y_train))    # Gives the R2 value for the training set
dtr.score(x_test,y_test)  # Gives the R2 value for the test set
# Out:
# 0.8368972794176226
# 0.8058459798835955
