# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitanysaraswat/Advanced-Analytics-Using-Statistics/blob/main/Lecture9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
from numpy import random
from collections import Counter
from numpy.linalg import inv
from numpy.linalg import eig
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
import pylab
from pylab import legend
from pylab import plot, show, title, xlabel, ylabel
import scipy
from scipy import stats
from scipy.stats import binom,poisson,norm,t,expon,f
from sklearn.model_selection import train_test_split

# %%
norm.cdf(55,60,5)
# Out:
# np.float64(0.15865525393145707)

# %%
norm.cdf(-1,0,1)
# Out:
# np.float64(0.15865525393145707)

# %% [markdown]
# norm.cdf :
# - takes the value x axis value as an input and gives area(probablity) on left side as an output
#
# norm.ppf:
# - takes probability as an area on left side as an output and gives the value on xaxis as an output

# %%
norm.ppf(0.1589)# area of right
# Out:
# np.float64(-0.9989890412674265)

# %%
norm.cdf(1.5)
# Out:
# np.float64(0.9331927987311419)

# %%
norm.ppf(0.9331927987311419)
# Out:
# np.float64(1.4999999999999996)

# %%
norm.ppf(0.025)
# Out:
# np.float64(-1.9599639845400545)

# %%
norm.ppf(0.975)
# Out:
# np.float64(1.959963984540054)

# %%
norm.ppf(0.025)
# Out:
# np.float64(-1.9599639845400545)

# %%
norm.ppf(0.005)
# Out:
# np.float64(-2.575829303548901)

# %%
norm.ppf(0.99)
# Out:
# np.float64(2.3263478740408408)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# to reduce margin of error:
# - reduce confidence level (not a good idea)
# - increase the sample size (best idea )

# %% [markdown]
# as confidence level increases z increases so the sample size increases
# sample inc
#
# sigma population standard deviation
# std=0 if sample size=1
#
# popualtion standard deviation less than sample size will be low or less
#
# d/MOE decreases sample size increasess
#
# sigma/squareroot of n == standard error of mean

# %%
n=300
sample_mean=1800
stdev =70
cl=0.99
z=np.abs(norm.ppf((1-cl)/2))
z
# interval estimate at 95%LevelFormatter
# Out:
# np.float64(1.959963984540054)

# %%
Xbar=1800 #sample mean

# %%
t = np.abs(t.ppf((1-0.99)/2,n-1))
t


# size = upper_est - low_est
# Out:
# np.float64(2.5923718841159307)

# %%
low_est = Xbar - t*stdev/n**0.5
upper_est = Xbar + t*stdev/n**0.5
print(low_est)
print(upper_est)
# Out:
# 1792.046706930732
# 1807.953293069268

# %%
stats.t.interval(cl,n-1,Xbar,stdev/n**0.5)
# stats.t.interval will take confidence interval degree of freedom, samplesize-1,stdev=standard deviation
# Out:
# (np.float64(1792.046706930732), np.float64(1807.953293069268))

# %% [markdown]
# # Inference
# - inference means conclusion
# ## step1:
# establish and null hpothesis(h0) and alternative hypothesis(h1/ha)
# - h0-defender approach
# - h0-prover appraoch
#
# Null hypothesis is made in such a way if it is found to be true than
# - no action is required
# - no decision is required
# - no changes is required
#
# EX:- min salary is 40K:
# - h0 s>=40k
# - h1 s<40k
# - error is only on left so it is called left tail test
#
#
# EX- max time for delievery in 20min:
#
# - h0 t<=20
# - ha t>20
# - error is only on right so it is called right tail test
#
# Two tail test:
#
# health parameter(blood group)
# rainfall
#
# ## Step2:
#  establish confidence level and level of significance
#  - level significance percentage(100 - confidence level) fractions(1-confidence level)
#
# ## step3:
# - choose the appropriate statistical test
#
# ## step 4:
#  - calculate the value of test statistics and small p -value
#
# ## step 5:
# - compare the value from (step4) against the level of significance
# - IF THE P-VALUE IS LESS THAN THE LEVEL OF SIGNIFICANCE THAN WE REJECT THE NULL HYPOTHESIS
# - IF THE P-VALUE IS MORE THAN THE LEVEL OF SIGNIFICANCE THAN WE DO NOT REJECT THE NULL HYPOTHESIS
#
# use the word
# - reject the null hypothesis
# - or do not reject hypothesis
#
# YOU CAN ONLY ACCEPT WHEN SAMPLE DATA = POPULATION PARAMETER

# %% [markdown]
# Type 1 error:
# - is committed when we reject a null hypothesis which is actually true
#
# type 2 error:
# - when we do not reject null hypothesis which is actually false
#
# WHAT IS P VALUE:
#
# assumming hypothesis to be true p value gives the probability of finding a value as extreme  as we as i have observing/found
#
# SS=PP+ACTUAL DIFF +CV
#
# 39.6=40
# IF THE DIFFERENCE IS SMALL B/W SS AND PP IS SMALL YOU DONT REHJECT TYPE1
#
# 33.6 =40
# IF THE DIFFERENCE IS SMALL B/W SS AND PP IS  REHJECT TYPE1

# %% [markdown]
# ![NULLHP.webp](data:image/webp;base64,...)
