# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitanysaraswat/Advanced-Analytics-Using-Statistics/blob/main/100python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Write a Python program to print "Hello, World!".
# 2. Write a program to check if a number is even or odd.
# 3. Write a program to find the factorial of a number.
# 4. Write a program to check if a string is a palindrome.
# 5. Write a program to find the largest element in an array.
# 6. Write a program to reverse a string.
# 7. Write a program to check if a number is prime.
# 8. Write a program to find the sum of all elements in an array.
# 9. Write a program to check if a string is an anagram.
# 10. Write a program to calculate the square root of a number.
# 11. Write a program to count the number of vowels in a string.
# 12. Write a program to find the second largest element in an array.
# 13. Write a program to find the sum of all even numbers in an array.
# 14. Write a program to check if a year is a leap year.
# 15. Write a program to calculate the factorial of a number using recursion.
# 16. Write a program to find the length of a string.
# 17. Write a program to find the GCD (Greatest Common Divisor) of two numbers.
# 18. Write a program to remove duplicate elements from an array.
# 19. Write a program to check if a string is a palindrome without using any built-in functions.
# 20. Write a program to find the sum of the digits of a number.
