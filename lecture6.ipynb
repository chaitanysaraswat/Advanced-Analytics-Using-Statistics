# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitanysaraswat/Advanced-Analytics-Using-Statistics/blob/main/lecture6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_excel('/content/drive/MyDrive/My pitch/CDAC_DataBook.xlsx',sheet_name='faithful')

# %%
df.head()
# Out:
#    eruptions  waiting
# 0      3.600       79
# 1      1.800       54
# 2      3.333       74
# 3      2.283       62
# 4      4.533       85

# %%
x1=df.eruptions
len(x1)
# Out:
# 272

# %%
sum(x1)/len(x1)
# Out:
# 3.487783088235294

# %%
import numpy as np
np.mean(x1)
# Out:
# np.float64(3.4877830882352936)

# %%
np.median(x1)
# Out:
# np.float64(4.0)
