# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitanysaraswat/Advanced-Analytics-Using-Statistics/blob/main/lecture6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_excel('/content/drive/MyDrive/My pitch/CDAC_DataBook.xlsx',sheet_name='faithful')

# %%
df.head()
# Out:
#    eruptions  waiting
# 0      3.600       79
# 1      1.800       54
# 2      3.333       74
# 3      2.283       62
# 4      4.533       85

# %%
x1=df.eruptions
len(x1)
# Out:
# 272

# %%
sum(x1)/len(x1)
# Out:
# 3.487783088235294

# %%
import numpy as np
np.mean(x1)
# Out:
# np.float64(3.4877830882352936)

# %%
np.median(x1)
# Out:
# np.float64(4.0)

# %% [markdown]
# Dispersion/variance:
# - Inter quartile range
# - Range
#
#
# Q why range is not good for dispersion
# - range  it can affected by outlier
# - it uses  only two value min and max it doesn't care abt other values
#
# q3-q1=75th quartile - 25th quartile= IQR
# 25 th quartile is median
# 75 th percentile 82 means that all student are below 82 are 75 percent student

# %%
import scipy
from scipy import stats

# %%
stats.mode(x1)# 1.87 number is repating 8times
# Out:
# ModeResult(mode=np.float64(1.867), count=np.int64(8))

# %%
from collections import Counter
(Counter(x1).most_common())
# Out:
# [(1.867, 8),
#  (4.5, 8),
#  (1.833, 7),
#  (4.7, 6),
#  (1.75, 6),
#  (4.8, 6),
#  (4.0, 6),
#  (4.533, 5),
#  (4.083, 5),
#  (3.833, 5),
#  (4.333, 5),
#  (3.6, 4),
#  (1.8, 4),
#  (4.35, 4),
#  (4.25, 4),
#  (1.883, 4),
#  (2.0, 4),
#  (4.167, 4),
#  (4.417, 4),
#  (4.6, 4),
#  (4.15, 4),
#  (4.583, 4),
#  (3.917, 3),
#  (1.967, 3),
#  (2.017, 3),
#  (4.567, 3),
#  (2.1, 3),
#  (4.633, 3),
#  (1.817, 3),
#  (1.983, 3),
#  (4.933, 3),
#  (2.2, 3),
#  (4.367, 3),
#  (4.233, 3),
#  (4.45, 3),
#  (3.333, 2),
#  (2.167, 2),
#  (3.85, 2),
#  (4.433, 2),
#  (4.3, 2),
#  (4.467, 2),
#  (4.033, 2),
#  (4.833, 2),
#  (2.233, 2),
#  (4.133, 2),
#  (4.1, 2),
#  (4.067, 2),
#  (3.95, 2),
#  (4.817, 2),
#  (4.667, 2),
#  (4.9, 2),
#  (1.783, 2),
#  (3.767, 2),
#  (1.917, 2),
#  (2.033, 2),
#  (2.4, 2),
#  (3.567, 2),
#  (3.5, 2),
#  (1.933, 2),
#  (2.083, 2),
#  (2.417, 2),
#  (2.25, 2),
#  (4.267, 2),
#  (4.117, 2),
#  (1.85, 2),
#  (4.283, 2),
#  (2.283, 1),
#  (2.883, 1),
#  (1.95, 1),
# ...

# %%
max(x1)-min(x1)
# Out:
# 3.4999999999999996

# %%
np.ptp(x1)
# Out:
# np.float64(3.4999999999999996)

# %% [markdown]
# what iqr is filling the gap of range?
# IQR is filling the range becoz it is removing outliers from data
#
# 75th percentile is 20
# then 75percent of data is less than 20
#
# ---

# %%
IQR=np.percentile(x1,75)-np.percentile(x1,25)
IQR
# Out:
# np.float64(2.2915)

# %% [markdown]
# - i=1+(n+1)*p/100  index of iqr
# wil give i(index)
# the n=number of values and p is percentile u want to find
# i=1+(23-1)*25/100
# ---

# %%
x2=[4,1,3,6,7,4,3,8,4,9,1,2,3]
x2=
len(x2)
# Out:
# 13

# %% [markdown]
# - take x no of element.
# - take mean of it.
# - x subtract mean(x-mean).
# - sum of it will always give zero.
# - to avoid it we are squaring elements than take sum amd mean it.
# ---
# - as number become consistent the std will go down deviation will go down.
# - as the variation data decraease variation and std decrease
# - coeficient of variation cv should be low (CV = (Standard Deviation / Mean) * 100) learn about it
#
# - feature engineering is creating column on basis of existing data
# - why take square not mode in linear regression for std
# - sigma and mu of each element units(kg etc ) need to be same and cv should become dimensionalless
#
# ---

# %% [markdown]
# Sample variance

# %%
x2=[4,3,6,5,7,9,7,3]
print("variance",np.var(x2))
print("std",np.std(x2))
# Out:
# variance 4.0
# std 2.0

# %%
np.var(x2,ddof=1)
# Out:
# np.float64(4.571428571428571)

# %%
np.std(x2,ddof=1)
# Out:
# np.float64(2.138089935299395)

# %% [markdown]
# peak on left side
#
# distribution is skewed to right
#
# positively skewed (smaller number frequency is more)
#
# skewness > 0
#
# ---

# %% [markdown]
# peak in the centre (normal bell shaped graph)
#
# distribution is symmetric
#
# skewness=0
#
# ---

# %% [markdown]
# peak is on the right side
#
# distribution is skewed to the the lrft
#
# negatively skewed
#
# skewness<0

# %% [markdown]
# Distribution for discrete data:
# - binomial
# - poisso dis
#
# continuous
# - exponential
# - normal
# - studentT

# %% [markdown]
# Bionomial distribution:
#
# - is used when there are only two possible occurences and historical probablity is known

# %%
from scipy.stats import binom
# pmf proabability mass function is used for finding the exact number
#it rains exactly 10 days  we use pmf
# cdf cumulative distribtion funcrtion when we want 0 find upto a particular number
# upto 5 will have 0-5 we will using cdf

# chances of rain on any given isin june is mumbai is 0.7
# a. it rains for exactly 10 display

# case number three included days will be 10
binom.pmf(10,15,0.7)
# pmf will be used for exact number
# cdf will be used upto a number
# more than a number 1-(n-1)cdf
1-binom.cdf(9,15,0.7)
# Out:
# np.float64(0.20613038097752098)

# %% [markdown]
# possion:
# - we are concerned of the number of times the event occur.not probabilty
# - mean number of occurence =n*p
# - as a probabilty tends to zero ,then bionomial per time

# %%
# a exactly 12 incidents taking place today
from scipy.stats import poisson
poisson.pmf(12,15)
# a upto 12 incidents taking place today
print(poisson.cdf(12,15))
# a minimum 12 incidents taking place today
print(1-poisson.cdf(11,15))
print(poisson.sf(11,15))#print(poisson.sf(11,15))==1-poisson.cdf(11,15)
# Out:
# 0.2676110333925769
# 0.8152482009760685
# 0.8152482009760685

# %% [markdown]
# TO DEFINE BELL SHAPED CURVE MEAN AND STD WILL BE GIVEN
# Q.MEAN=16hrs STD.DEV=2.3hrs
# <=14HRS
# >=14HRS
# 13<= <=17
# MEASURE AREA FROM LEFT HAND SIDE IN GRAPH

# %%
from scipy.stats import norm,t
norm.cdf(14,16,2.3)
# Out:
# np.float64(0.19226902649831168)

# %%
1-norm.cdf(14,16,2.3)
# norm.sf(14,16,2.3)
# Out:
# np.float64(0.8077309735016883)
