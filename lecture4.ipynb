# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitanysaraswat/Advanced-Analytics-Using-Statistics/blob/main/lecture4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_excel('/content/drive/MyDrive/My pitch/CDAC_DataBook.xlsx',sheet_name='ERPData')
df.head()
# Out:
#   MaterialID Location  Quantity
# 0    TMI-43T    MWH-4        34
# 1    AXCP-78    MWH-1        67
# 2    LXCV-21    MWH-2        27
# 3    AXCP-78    MWH-5        65
# 4    AXCP-78    MWH-4        36

# %%
grp1=df.groupby('MaterialID')
grp1.get_group('SDRT-67')
# Out:
#    MaterialID Location  Quantity
# 10    SDRT-67    MWH-1        34
# 11    SDRT-67    MWH-4        58
# 16    SDRT-67    MWH-5        12
# 17    SDRT-67    MWH-5       102
# 41    SDRT-67    MWH-1        57
# 42    SDRT-67    MWH-2        31

# %%
grp1.Quantity.agg(np.sum)
# Out:
# /tmp/ipykernel_9626/4207539702.py:1: FutureWarning: The provided callable <function sum at 0x7fde407f8860> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grp1.Quantity.agg(np.sum)
# MaterialID
# AXCP-78    898
# DDBN-89    383
# GCVB-79    182
# LXCV-21    243
# SDRT-67    294
# TMI-43T    885
# Name: Quantity, dtype: int64

# %%
grp1=df.groupby(['Location','MaterialID'])
grp1.groups
# Out:
# {('MWH-1', 'AXCP-78'): [1, 24, 25, 39, 48], ('MWH-1', 'DDBN-89'): [26, 40, 49], ('MWH-1', 'SDRT-67'): [10, 41], ('MWH-1', 'TMI-43T'): [9], ('MWH-2', 'AXCP-78'): [46], ('MWH-2', 'DDBN-89'): [45], ('MWH-2', 'GCVB-79'): [8, 15, 35, 36], ('MWH-2', 'LXCV-21'): [2], ('MWH-2', 'SDRT-67'): [42], ('MWH-2', 'TMI-43T'): [7], ('MWH-3', 'AXCP-78'): [47], ('MWH-3', 'DDBN-89'): [43], ('MWH-3', 'LXCV-21'): [44], ('MWH-3', 'TMI-43T'): [14], ('MWH-4', 'AXCP-78'): [4], ('MWH-4', 'DDBN-89'): [22, 30], ('MWH-4', 'SDRT-67'): [11], ('MWH-4', 'TMI-43T'): [0, 5, 6, 12, 13, 18, 19, 20, 21, 31, 32], ('MWH-5', 'AXCP-78'): [3, 37, 38], ('MWH-5', 'DDBN-89'): [23], ('MWH-5', 'GCVB-79'): [34], ('MWH-5', 'LXCV-21'): [27, 28, 29], ('MWH-5', 'SDRT-67'): [16, 17], ('MWH-5', 'TMI-43T'): [33]}

# %%
grp1.Quantity.agg('sum')
# Out:
# Location  MaterialID
# MWH-1     AXCP-78       548
#           DDBN-89       130
#           SDRT-67        91
#           TMI-43T       120
# MWH-2     AXCP-78        85
#           DDBN-89        69
#           GCVB-79       156
#           LXCV-21        27
#           SDRT-67        31
#           TMI-43T        29
# MWH-3     AXCP-78        29
#           DDBN-89        38
#           LXCV-21        42
#           TMI-43T        65
# MWH-4     AXCP-78        36
#           DDBN-89        75
#           SDRT-67        58
#           TMI-43T       559
# MWH-5     AXCP-78       200
#           DDBN-89        71
#           GCVB-79        26
#           LXCV-21       174
#           SDRT-67       114
#           TMI-43T       112
# Name: Quantity, dtype: int64

# %%
ind=np.where((df.Location	=='MWH-1') & ((df.MaterialID	=='AXCP-78')))
print(ind)
df2=df.iloc[ind[0]]
df2.Quantity.sum()
# Out:
# (array([ 1, 24, 25, 39, 48]),)
# np.int64(548)

# %%
newdf=grp1.agg(['sum','mean','size'])
newdf
# Out:
#                     Quantity
#                          sum        mean size
# Location MaterialID
# MWH-1    AXCP-78         548  109.600000    5
#          DDBN-89         130   43.333333    3
#          SDRT-67          91   45.500000    2
#          TMI-43T         120  120.000000    1
# MWH-2    AXCP-78          85   85.000000    1
#          DDBN-89          69   69.000000    1
#          GCVB-79         156   39.000000    4
#          LXCV-21          27   27.000000    1
#          SDRT-67          31   31.000000    1
#          TMI-43T          29   29.000000    1
# MWH-3    AXCP-78          29   29.000000    1
#          DDBN-89          38   38.000000    1
#          LXCV-21          42   42.000000    1
#          TMI-43T          65   65.000000    1
# MWH-4    AXCP-78          36   36.000000    1
#          DDBN-89          75   37.500000    2
#          SDRT-67          58   58.000000    1
#          TMI-43T         559   50.818182   11
# ...

# %%
newdf.loc['MWH-1']
# Out:
#            Quantity
#                 sum        mean size
# MaterialID
# AXCP-78         548  109.600000    5
# DDBN-89         130   43.333333    3
# SDRT-67          91   45.500000    2
# TMI-43T         120  120.000000    1

# %% [markdown]
# # Sorting of Data Frame

# %%
df_sorted=df.sort_values('Quantity')
print(df_sorted.head(),end='\n\n')
print(df_sorted.tail())
# Out:
#    MaterialID Location  Quantity
# 8     GCVB-79    MWH-2        10
# 16    SDRT-67    MWH-5        12
# 34    GCVB-79    MWH-5        26
# 30    DDBN-89    MWH-4        27
# 2     LXCV-21    MWH-2        27
#
#    MaterialID Location  Quantity
# 25    AXCP-78    MWH-1       109
# 33    TMI-43T    MWH-5       112
# 9     TMI-43T    MWH-1       120
# 39    AXCP-78    MWH-1       145
# 24    AXCP-78    MWH-1       152

# %%
df_sorted=df.sort_values('Quantity',ascending=False)
print(df_sorted.head(),end='\n\n')
print(df_sorted.tail())
# Out:
#    MaterialID Location  Quantity
# 24    AXCP-78    MWH-1       152
# 39    AXCP-78    MWH-1       145
# 9     TMI-43T    MWH-1       120
# 33    TMI-43T    MWH-5       112
# 25    AXCP-78    MWH-1       109
#
#    MaterialID Location  Quantity
# 2     LXCV-21    MWH-2        27
# 30    DDBN-89    MWH-4        27
# 34    GCVB-79    MWH-5        26
# 16    SDRT-67    MWH-5        12
# 8     GCVB-79    MWH-2        10

# %%
df_sorted=df.sort_values(['MaterialID', 'Location',  'Quantity'])
df_sorted.head()
# Out:
#    MaterialID Location  Quantity
# 1     AXCP-78    MWH-1        67
# 48    AXCP-78    MWH-1        75
# 25    AXCP-78    MWH-1       109
# 39    AXCP-78    MWH-1       145
# 24    AXCP-78    MWH-1       152

# %%
df_sorted=df.sort_values(['MaterialID', 'Location',  'Quantity'],ascending=[True,False,True])
df_sorted.head()
# Out:
#    MaterialID Location  Quantity
# 3     AXCP-78    MWH-5        65
# 37    AXCP-78    MWH-5        65
# 38    AXCP-78    MWH-5        70
# 4     AXCP-78    MWH-4        36
# 47    AXCP-78    MWH-3        29

# %%
pune=pd.read_excel('/content/drive/MyDrive/My pitch/CDAC_DataBook.xlsx',sheet_name='Pune')
print(pune.head())
mumbai=pd.read_excel('/content/drive/MyDrive/My pitch/CDAC_DataBook.xlsx',sheet_name='Mumbai')
mumbai.head()
# Out:
#       Name      Subject Grade
# 0   Rakesh       Python     A
# 1    Manoj     MLPython     C
# 2  Vaibhav   Statistics     B
# 3   Hitesh   CommSkills     A
# 4   Suyash  ProjectMgmt     B
#        Name     Subject Grade
# 0   Vaibhav   Six Sigma     A
# 1   Deepika  Statistics     B
# 2     Arjun  CommSkills     A
# 3    Chetan      Python     A
# 4  Abhishek    MLPython     B

# %%
df1=pd.concat([pune,mumbai])
df1
# Out:
#        Name      Subject Grade
# 0    Rakesh       Python     A
# 1     Manoj     MLPython     C
# 2   Vaibhav   Statistics     B
# 3    Hitesh   CommSkills     A
# 4    Suyash  ProjectMgmt     B
# 0   Vaibhav    Six Sigma     A
# 1   Deepika   Statistics     B
# 2     Arjun   CommSkills     A
# 3    Chetan       Python     A
# 4  Abhishek     MLPython     B

# %%
pd.merge(pune,mumbai)#it is empty becoz any row exactly similar with Name ,Subject ,Grade
# Out:
# Empty DataFrame
# Columns: [Name, Subject, Grade]
# Index: []

# %%
mumbai.loc[4,'Grade']
# Out:
# 'B'

# %%
pd.merge(pune,mumbai,on='Subject') #represent x=pune,y=mumbai it is by default
# Out:
#     Name_x     Subject Grade_x    Name_y Grade_y
# 0   Rakesh      Python       A    Chetan       A
# 1    Manoj    MLPython       C  Abhishek       B
# 2  Vaibhav  Statistics       B   Deepika       B
# 3   Hitesh  CommSkills       A     Arjun       A

# %%
pd.merge(pune,mumbai,on='Subject',how='inner') #x=pune,y=mumbai
# Out:
#     Name_x     Subject Grade_x    Name_y Grade_y
# 0   Rakesh      Python       A    Chetan       A
# 1    Manoj    MLPython       C  Abhishek       B
# 2  Vaibhav  Statistics       B   Deepika       B
# 3   Hitesh  CommSkills       A     Arjun       A

# %%
pd.merge(pune,mumbai,on=['Subject','Grade']) #represent x=pune,y=mumbai it is by default
# Out:
#     Name_x     Subject Grade   Name_y
# 0   Rakesh      Python     A   Chetan
# 1  Vaibhav  Statistics     B  Deepika
# 2   Hitesh  CommSkills     A    Arjun

# %% [markdown]
# whenever u gave answers in interview give short and crisp but not incomplete answers

# %%
pd.merge(pune,mumbai,on='Subject',how='outer')#outer join uses or
# Out:
#     Name_x      Subject Grade_x    Name_y Grade_y
# 0   Hitesh   CommSkills       A     Arjun       A
# 1    Manoj     MLPython       C  Abhishek       B
# 2   Suyash  ProjectMgmt       B       NaN     NaN
# 3   Rakesh       Python       A    Chetan       A
# 4      NaN    Six Sigma     NaN   Vaibhav       A
# 5  Vaibhav   Statistics       B   Deepika       B

# %%
pd.merge(pune,mumbai,on='Subject',how='left')#left join uses first df
# Out:
#     Name_x      Subject Grade_x    Name_y Grade_y
# 0   Rakesh       Python       A    Chetan       A
# 1    Manoj     MLPython       C  Abhishek       B
# 2  Vaibhav   Statistics       B   Deepika       B
# 3   Hitesh   CommSkills       A     Arjun       A
# 4   Suyash  ProjectMgmt       B       NaN     NaN

# %%
pd.merge(pune,mumbai,on='Subject',how='right')#right join uses first df
# Out:
#     Name_x     Subject Grade_x    Name_y Grade_y
# 0      NaN   Six Sigma     NaN   Vaibhav       A
# 1  Vaibhav  Statistics       B   Deepika       B
# 2   Hitesh  CommSkills       A     Arjun       A
# 3   Rakesh      Python       A    Chetan       A
# 4    Manoj    MLPython       C  Abhishek       B
