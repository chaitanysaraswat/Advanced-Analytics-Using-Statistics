# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitanysaraswat/Advanced-Analytics-Using-Statistics/blob/main/lecture10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)
from numpy import random
from collections import Counter
from numpy.linalg import inv
from numpy.linalg import eig
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
import pylab
from pylab import legend
from pylab import plot, show, title, xlabel, ylabel
import scipy
from scipy import stats
from scipy.stats import binom,poisson,norm,t,expon,f
from sklearn.model_selection import train_test_split
import statsmodels
from statsmodels import stats
from statsmodels.stats import weightstats as ssw

# %%
df=pd.read_excel('/content/drive/MyDrive/My pitch/CDAC_DataBook.xlsx',sheet_name='faithful')
df.head()
# Out:
#    eruptions  waiting
# 0      3.600       79
# 1      1.800       54
# 2      3.333       74
# 3      2.283       62
# 4      4.533       85

# %%
xbar=np.mean(erupt)
std=np.std(erupt,ddof=1)
n=len(erupt)
z=(xbar-3.37)/(std/n**0.5)

# %%
erupt=df.eruptions
xbar=np.mean(erupt)
n=len(erupt)
sd=np.std(erupt,ddof=1)
print(xbar)
erupt
# Out:
# 3.4877830882352936
# 0      3.600
# 1      1.800
# 2      3.333
# 3      2.283
# 4      4.533
#        ...
# 267    4.117
# 268    2.150
# 269    4.417
# 270    1.817
# 271    4.467
# Name: eruptions, Length: 272, dtype: float64

# %%
z=(xbar-3.37)/(sd/n**0.5)
z
# Out:
# np.float64(1.7019251649638614)

# %% [markdown]
# # 1-sample z test/ 1 sample t test:
#
# - Used to check whether the difference betweent the sample mean and claim value can be ignored or not.(ssw.ztest use smaller,larger,two-sided)
#
# - z-test is not used for categorical data but for continuous data.
# - Used to check whether the difference betweent the sample mean and claim value is statistically significant or not

# %% [markdown]
# 2 sample t -test :
# - this test is used when the difference of averages of two independent samples
# has to be compare d against a claim value and to establish whether there diff statsically significant or not.
# - area of application:

# %% [markdown]
# 1  h0 u>=3.6
#   ha u<3.6
#
# 2 cl=95%
# los=5%
#
# 3 1 sample z test
#
# 4 ts p-value

# %%
ssw.ztest(erupt,value=3.6,alternative='smaller')
# Out:
# (np.float64(-1.621495827018525), np.float64(0.052455672107759366))

# %%
print(ssw.ztest(erupt,value=3.7,alternative='smaller')) # first one z second p-value if p smaller than los(0.05)
norm.ppf(0.05)
# Out:
# (np.float64(-3.06646147570652), np.float64(0.0010830435959524984))
# np.float64(-1.6448536269514729)

# %% [markdown]
# rejection will happen when the magnitude

# %%
z=(3.487-3.53)/(sd/n**0.5)
z
# Out:
# -0.6213352289358334

# %%
norm.cdf(z)
# Out:
# np.float64(0.2671895395328251)

# %% [markdown]
# los=5%
# value on x through ppf
# if it is less
#
# start point of 5% on standard normal curve is -1.6448536269514729
#
# and z is -3.066461475706521 and p-value(0.0010830435959524984)
#
# because the z-value is lesser than start point of 5% so we reject the NULL HYPOTHESIS.
#
# Upto -1.645 is okay to be DO NOT REJECT.
#
# ---
#
# There is 2 options to choose between Rejection or not to NULL HYPOTHESIS
# 1. Compare with z-value:
#
# **Rejection will happen if z-value is more than 5%**
#
# z-value is value on x-axis, if it's magnitude is more than Zc then we REJECT
#
# 2. Compare with p-value:
#
# p-value is percentage, if it's magnitude is less than LOS then REJECT

# %%
ssw.ztest(erupt,value=3.53,alternative='smaller') #NULL HYPOTHESIS WILL NOT BE REJECTED BCOZ P VALUE GREATER THAN 0.05 (LOS)
# Out:
# (np.float64(-0.6100198729369251), np.float64(0.27092432161445423))

# %%
#U(mean) will not exceed 3.37
ssw.ztest(erupt,value=3.37,alternative='larger') #NULL hypothesis will be rejected p value is samller 0.05 and and 1.7 is x axis figure
# Out:
# (np.float64(1.7019251649638607), np.float64(0.044384698843295746))

# %%
norm.ppf(0.95)
# Out:
# np.float64(1.6448536269514722)

# %%
z=(xbar-3.57)/(sd/n**0.5)
zc=norm.ppf(0.05)
zc
# Out:
# np.float64(-1.6448536269514729)

# %%
df.waiting
# Out:
# 0      79
# 1      54
# 2      74
# 3      62
# 4      85
#        ..
# 267    81
# 268    46
# 269    90
# 270    46
# 271    74
# Name: waiting, Length: 272, dtype: int64

# %%
df1=df.waiting
xbar=np.mean(df1)
n=len(df1)
sd=np.std(df1,ddof=1)
print(xbar)
# Out:
# 70.8970588235294

# %% [markdown]
# if it is right tail test we have to use larger in ssw.test
#
# if it is two tail test  than we to use two-sided in ssw.test

# %%
ssw.ztest(df1,value=75,alternative='smaller') #NULL hypothesis will be rejected p value is samller 0.05 and and 1.7 is x axis figure
# Out:
# (np.float64(-4.9773865275793225), np.float64(3.222427049500608e-07))

# %%
z=(xbar-75)/(sd/n**0.5)
z
# Out:
# np.float64(-4.977386527579323)

# %%
norm.ppf(0.95)
# Out:
# np.float64(1.6448536269514722)

# %%
x2=xbar+1.645/(sd/n**0.5)
x2
# Out:
# np.float64(72.89265185928217)

# %% [markdown]
# 1. A bottled water company claims that the average quantity filled in each bottle is 1 liter. A consumer rights group suspects that the company is filling less than 1 liter on average. Form the null and alternative hypotheses using the defender’s approach.
#
# 2. A university claims that the average IQ score of students admitted to a special program is 110. An education analyst believes the actual average IQ is different from 110. Form the null and alternative hypotheses using the defender’s approach.
#
# 3. A mobile battery manufacturer states that the average battery backup time is 12 hours. A customer association feels that the average backup time is lower than claimed. Form the null and alternative hypotheses using the defender’s approach.
#
# 4. A hospital administration claims that the average waiting time in the emergency department is 15 minutes. Patients believe that the waiting time is actually more than 15 minutes. Form the null and alternative hypotheses using the defender’s approach.
#
# 5. A fertilizer company claims that each bag contains an average of 50 kg fertilizer. A distributor suspects that the bags contain less than 50 kg on average. Form the null and alternative hypotheses using the defender’s approach.
#
# 6. A coaching institute advertises that the average score of its students in a competitive exam is 78 marks. A rival institute claims that the actual average is not 78 marks. Form the null and alternative hypotheses using the defender’s approach.
#
# 7. A restaurant chain claims that the average delivery time is 30 minutes. Customers believe that deliveries are taking longer than 30 minutes on average. Form the null and alternative hypotheses using the defender’s approach.
#
# 8. A cement manufacturer claims that the average compressive strength of its cement is 5000 psi. A construction engineer suspects that the actual average strength is lower. Form the null and alternative hypotheses using the defender’s approach.
#
# 9. An airline claims that the average baggage handling time is 20 minutes. Travelers suspect that the actual average handling time exceeds 20 minutes. Form the null and alternative hypotheses using the defender’s approach.
#
# 10. A pharmaceutical company claims that a vitamin tablet contains an average of 100 mg of Vitamin C. A regulatory authority suspects that the actual average content is less than 100 mg. Form the null and alternative hypotheses using the defender’s approach.

# %%
zc=norm.ppf(0.95)

# %% [markdown]
# if i wnat to check gender affect salary or not
# - group box plot
# - inferential stats( 2 sample t -test)
# - null hypothesis(sm=sf Sm-Sf=0) malesalary - female salary

# %% [markdown]
# Travel in Blore is atleast 15 min more than Mumbai
#
# Blore
# - Sample size 50
# - Avg time 45
# - Std Dev 10.5
#
# Mumbai
# - Sample size 60
# - Avg time 34
# - Std Dev 5.6

# %%
df.head()
# Out:
#    eruptions  waiting
# 0      3.600       79
# 1      1.800       54
# 2      3.333       74
# 3      2.283       62
# 4      4.533       85

# %%
df1=df.iloc[20:60]
df2=df.iloc[120:170]

# %%
df1.shape
# Out:
# (40, 2)

# %%
erupt1=df1.eruptions
erupt2=df2.eruptions

# %% [markdown]
# null hpothesis:
# - h0: mean(erupt2)-mean(erupt1)>=0.12
# - ha:mean(erupt1)-mean(erupt2)<=0.12

# %%
ssw.ztest(erupt2,erupt1,value=0.12,alternative='smaller')
# Out:
# (np.float64(-0.3196536558502502), np.float64(0.3746154475542464))

# %%
x1=np.mean(erupt2)-np.mean(erupt1)
x1
# Out:
# np.float64(0.040189999999999504)

# %% [markdown]
# h0 mean(erupt2) -mean(erupt1)=0
#
# two sided tail test
# ![image.png](data:image/png;base64,...)

# %%
ssw.ztest(erupt2,erupt1,0,alternative='two-sided')
# Out:
# (np.float64(0.160968305082337), np.float64(0.8721183639481939))

# %%
nr=np.mean(erupt2)-np.mean(erupt1)-0.12

dr=(np.std(erupt1,ddof=1))**2/len(erupt1)+(np.std(erupt2,ddof=1)**2/len(erupt2))**0.5
nr/dr
# Out:
# np.float64(-0.39930408319803884)

# %%
df=pd.read_csv("/content/drive/MyDrive/My pitch/6-Churn_ModellingDataSet.csv")
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df2=df[['Age','Exited']]
df2
# Out:
#       Age  Exited
# 0      42       1
# 1      41       0
# 2      42       1
# 3      39       0
# 4      43       0
# ...   ...     ...
# 9995   39       0
# 9996   35       0
# 9997   36       1
# 9998   42       1
# 9999   28       0
#
# [10000 rows x 2 columns]

# %%
df2.isnull().sum()
# Out:
# Age       0
# Exited    0
# dtype: int64

# %% [markdown]
# pick low salary even if  profile is good if u want to pick passion comes into the picture
#
# at certain age managerial skills will work
#
# job will depend on personal and communication skills
#
# learn to be foresighted
